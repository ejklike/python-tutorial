# %% [markdown]
# # `n` little indians

# %% [markdown]
# ![](https://i.ytimg.com/vi/O5-J7yS8Z-0/hq720.jpg?sqp=-oaymwEhCK4FEIIDSFryq4qpAxMIARUAAAAAGAElAADIQj0AgKJD&rs=AOn4CLBkOaa1U1eUwBpWol16BHrsS8z7pQ)

# %% [markdown]
# ### How to print 10 little indian boys lyrics?

# %% [markdown]
# 1. Write the lyrics manually and use `print()` function.

# %%
lyrics = """One little, two little, three little Indians,
Four little, five little, six little Indians,
Seven little, eight little, nine little Indians,
Ten little Indian boys"""
print(lyrics)
# Out:
# One little, two little, three little Indians,
# Four little, five little, six little Indians,
# Seven little, eight little, nine little Indians,
# Ten little Indian boys

# %% [markdown]
# ### However, what if there are 100 or 1000 little Indians? Would you still prefer to write them manually?

# %% [markdown]
# 2. Using Python statements!
# - `for` loop
# - `if-else` conditional
# - `range()`

# %%
def print_n_little_indian_lyrics(n_indian):
    # your code here
    # ...

# %%
print_n_little_indian_lyrics(10)
# Out:
# 1 little, 2 little, 3 little Indians,
# 4 little, 5 little, 6 little Indians,
# 7 little, 8 little, 9 little Indians,
# 10 little Indian boys.

# %%
print_n_little_indian_lyrics(30)
# Out:
# 1 little, 2 little, 3 little Indians,
# 4 little, 5 little, 6 little Indians,
# 7 little, 8 little, 9 little Indians,
# 10 little, 11 little, 12 little Indians,
# 13 little, 14 little, 15 little Indians,
# 16 little, 17 little, 18 little Indians,
# 19 little, 20 little, 21 little Indians,
# 22 little, 23 little, 24 little Indians,
# 25 little, 26 little, 27 little Indians,
# 28 little, 29 little, 30 little Indian boys.

# %%
print_n_little_indian_lyrics(100)
# Out:
# 1 little, 2 little, 3 little Indians,
# 4 little, 5 little, 6 little Indians,
# 7 little, 8 little, 9 little Indians,
# 10 little, 11 little, 12 little Indians,
# 13 little, 14 little, 15 little Indians,
# 16 little, 17 little, 18 little Indians,
# 19 little, 20 little, 21 little Indians,
# 22 little, 23 little, 24 little Indians,
# 25 little, 26 little, 27 little Indians,
# 28 little, 29 little, 30 little Indians,
# 31 little, 32 little, 33 little Indians,
# 34 little, 35 little, 36 little Indians,
# 37 little, 38 little, 39 little Indians,
# 40 little, 41 little, 42 little Indians,
# 43 little, 44 little, 45 little Indians,
# 46 little, 47 little, 48 little Indians,
# 49 little, 50 little, 51 little Indians,
# 52 little, 53 little, 54 little Indians,
# 55 little, 56 little, 57 little Indians,
# 58 little, 59 little, 60 little Indians,
# 61 little, 62 little, 63 little Indians,
# 64 little, 65 little, 66 little Indians,
# 67 little, 68 little, 69 little Indians,
# ...
