# %% [markdown]
# # Natural Language Processing (NLP)
#
# **GOAL**: Let's taste how to process natural language text using Python!

# %% [markdown]
# ### 0. Installation
#
# Before starting this tutorial, please be prepared by installing the two packages.
# - English: `nltk` package
# - Korean: `konlpy` package (+Java Development Kit)
#
# You can install them by running the following lines in Anaconda Prompt:
# ```
# >> pip install nltk
# >> pip install konlpy
# ```
#
# For details, see slides.

# %% [markdown]
# ### 1. English NLP using NLTK package
#
# [NLTK](https://www.nltk.org/) is a pioneering NLP package built in Python.
#
# First, import the `nltk` package and download a tokenizer and a pos tagger.

# %%
import nltk

nltk.download('punkt_tab') # tokenizer
nltk.download('averaged_perceptron_tagger_eng') # pos tagger
nltk.download('stopwords') # stopwords
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\dmlab\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\dmlab\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\dmlab\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# Try your own sentences. You can tokenize, POS tag, or extract nouns.

# %%
from nltk.corpus import stopwords

sentence = "By the end of this course I will be a great text data miner! 100% sure!"

# Tokenization
tokens = nltk.word_tokenize(sentence)
print(tokens)
print()

# POS tagging
tagged = nltk.pos_tag(tokens)
print(tagged)
print()

# Remove stopwords
tokens_no_stopwords = [t for t in tokens if t.lower() not in stopwords.words('english')]
print(tokens_no_stopwords)
print()

# Extract nouns
nouns = [word for word, tag in tagged if tag[:2] == 'NN']
print(nouns)
# Out:
# ['By', 'the', 'end', 'of', 'this', 'course', 'I', 'will', 'be', 'a', 'great', 'text', 'data', 'miner', '!', '100', '%', 'sure', '!']
#
# [('By', 'IN'), ('the', 'DT'), ('end', 'NN'), ('of', 'IN'), ('this', 'DT'), ('course', 'NN'), ('I', 'PRP'), ('will', 'MD'), ('be', 'VB'), ('a', 'DT'), ('great', 'JJ'), ('text', 'NN'), ('data', 'NNS'), ('miner', 'NN'), ('!', '.'), ('100', 'CD'), ('%', 'NN'), ('sure', 'JJ'), ('!', '.')]
#
# ['end', 'course', 'great', 'text', 'data', 'miner', '!', '100', '%', 'sure', '!']
#
# ['end', 'course', 'text', 'data', 'miner', '%']

# %% [markdown]
# ### 2. Korean NLP using KoNLPy pacakge
#
# [KoNLPy](https://konlpy.org/) is a Python package for NLP of Korean language.
#
# It contains famous Korean POS taggers such as Hannanum (`Hannanum`), Kkma(`Kkma`), and Open Korean Text (`Okt`, aka Twitter).
#
# Here, we will use Twitter tagger. Let's load it.

# %%
from konlpy.tag import Okt

okt = Okt()

# %% [markdown]
# Try your own sentence. You can tokenize, POS tag, or extract nouns and phrases.

# %%
sentence = '데이터 분석 수업이 넘나 재밌어서 현기증이 나요...ㅋ'
# sentence = '공부를 하면할수록 모르는게 많다는 것을 알게 됩니다. 배운건 많았는데... 다 까먹어버렸네요? ㅋㅋ 그래도 계속 공부합니다. 재밌으니까!'

# tokenization
tokens = okt.morphs(sentence)
print(tokens)
print()

# POS tagging
tagged = okt.pos(sentence)
print(tagged)
print()

# noun extraction
nouns = okt.nouns(sentence)
print(nouns)
print()
# Out:
# ['데이터', '분석', '수업', '이', '넘나', '재밌어서', '현기증', '이', '나요', '...', 'ㅋ']
#
# [('데이터', 'Noun'), ('분석', 'Noun'), ('수업', 'Noun'), ('이', 'Josa'), ('넘나', 'Verb'), ('재밌어서', 'Adjective'), ('현기증', 'Noun'), ('이', 'Josa'), ('나요', 'Eomi'), ('...', 'Punctuation'), ('ㅋ', 'KoreanParticle')]
#
# ['데이터', '분석', '수업', '현기증']
