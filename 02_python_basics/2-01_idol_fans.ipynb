# %% [markdown]
# # Idol Fans
#
# ![](https://wikidocs.net/images/page/258034/set_diagram.png)
#
# There are fans of NewJeans, IVE, and aespa.
# - People who like NewJeans: 철수, 영희, 민수, 지현, 서연
# - People who like IVE: 영희, 민수, 지수, 서연, 하나
# - People who like aespa: 철수, 지현, 지수, 서연, 나영
#
# Q. Among these, who likes both NewJeans and IVE but doesn't like aespa?

# %%
# define lists
fans_nj = ['철수', '영희', '민수', '지현', '서연']
fans_ive = ['영희', '민수', '지수', '서연', '하나']
fans_aespa = ['철수', '지현', '지수', '서연', '나영']

# or,
# fans_nj = '철수, 영희, 민수, 지현, 서연'.split(', ')
# fans_ive = '영희, 민수, 지수, 서연, 하나'.split(', ')
# fans_aespa = '철수, 지현, 지수, 서연, 나영'.split(', ')

# %% [markdown]
# We have a couple of options to find the common fans:

# %% [markdown]
# 1. Solve it using `for` loop.

# %% [markdown]
# 2. Use list comprehension

# %% [markdown]
# 3. Use `set` operations.
