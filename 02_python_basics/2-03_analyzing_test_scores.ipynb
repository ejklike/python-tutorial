# %% [markdown]
# # Analyzing Test Scores
#
# A class has just completed three different tests. You have been given the scores for one student as a tuple and the scores for all students as a list of tuples:

# %%
student_scores = [
    (85, 90, 78),  # Student 1: (Test 1, Test 2, Test 3)
    (92, 88, 95),  # Student 2
    (75, 80, 82),  # Student 3
    (98, 95, 90)   # Student 4
]

# %% [markdown]
# Your task is to write a Python code that performs the following operations:
#
# 1. Calculate the averages for Tests 1~3
# 2. Calculate the averages for Students 1~4
# 3. Identify the student with the highest average score
# 4. Identify the student with the lowest average score

# %%
# Calculate the averages for Tests 1~3

# %%
# Calculate the averages for Students 1~4

# %%
# Identify the student with the highest average score

# %%
# Identify the student with the lowest average score
