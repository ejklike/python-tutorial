# %% [markdown]
# ## Word Checker
#
# **Problem:** You are given a phrase and a list of words to check. Your task is to process the phrase by:
# 1. Converting the entire phrase to **lowercase**.
# 2. **Replacing** all commas `,` and periods `.` with an empty string `''`.
# 3. Splitting the phrase into a **list of words**.
# 4. Then, for each word in the provided `words_to_check` list, check if it exists in your processed phrase and print whether it was found or not.
#
# **Phrase:** `"Hello world, my name is John."`
#
# **Words to check:** `['world', 'name', 'python', 'hello']`
#
# **Expected Output:**
#
# ```
# Checking 'world': Found
# Checking 'name': Found
# Checking 'python': Not found
# Checking 'hello': Found
# ```

# %%
def word_checker(phrase, words_to_check=None):
    # your code here
    # ...

# %%
word_checker("Hello world, my name is John.")
# Out:
# Checking 'world': Found
# Checking 'name': Found
# Checking 'python': Not Found
# Checking 'hello': Found

# %%
word_checker("The quick brown fox jumps over the lazy dog. A world of adventure awaits those who dare to step outside their comfort zone and make a name for themselves. This is a simple phrase, but it's important to hello to everyone you meet.")
# Out:
# Checking 'world': Found
# Checking 'name': Found
# Checking 'python': Not Found
# Checking 'hello': Found
