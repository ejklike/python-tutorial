# %% [markdown]
# # Product Price Lookup
#
# Create a program that looks up the price of a product. Your program should have a pre-defined dictionary of products and their prices (e.g., `"coffee": 3.50, "tea": 2.50, "scone": 4.00`). It should then ask the user to enter a product name. If the product is in your dictionary, print its price. If it is not, print a message saying it's unavailable.
#
# Example 1:
#
# Input: `coffee`
#
# Output: `The price of coffee is $3.50`
#
# Example 2:
#
# Input: `cookie`
#
# Output: `cookie is not available.`

# %%
product_dict = {
    "coffee": 3.50, 
    "tea": 2.50, 
    "scone": 4.00
}

def price_lookup(item):
    # your code here
    # ...

# %%
price_lookup("coffee")
price_lookup("cookie")
# Out:
# The price of coffee is $3.50.
# cookie is not available.
