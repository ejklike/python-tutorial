# %% [markdown]
# # City Data
#
# You have a list of cities and their populations.
#
# **City Data:** `['Tokyo', 37400000, 'Delhi', 31100000, 'Shanghai', 27800000, 'Sao Paulo', 22400000]`
#
# **Problem:** The list is currently flat. Separate the city names and their populations into two distinct lists. Then, print the result.
#
# **Expected Output:**
#
# ```python
# Cities: ['Tokyo', 'Delhi', 'Shanghai', 'Sao Paulo']
# Populations: [37400000, 31100000, 27800000, 22400000]
# ```

# %%
city_data = ['Tokyo', 37400000, 'Delhi', 31100000, 'Shanghai', 27800000, 'Sao Paulo', 22400000]

# %%
# your code here
# ...
