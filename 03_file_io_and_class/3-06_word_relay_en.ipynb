# %% [markdown]
# # Problem: Word Relay (English)
#
# Create a function `find_next_word()` that finds words in the word list that start with the last character of the input word.
#
# Example:
# - Input: "crib"
# - Output: "between"
#
# The English words are listed in `./data/english_words.txt`.
#
# > If there are more than one word that all starts with the last syllable of an input word, you can use the `choice()` function from the `random` module to select one randomly:
#
# ```python
# random.choice([1, 2, 3]) # output is one of the three numbers
# ```
#
# > If there is no word that starts with the last syllable of an input word, return `None`.

# %%
def find_next_words(input_word):
    # your code here
    # ...

# %%
find_next_words("crib")
# Out:
# 'between'
