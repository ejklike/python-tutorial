# %% [markdown]
# # Word Counter
#
# Write a function `word_count` that takes a text file path as input and counts the occurrences of each word in the file.
#
# **Instructions:**
#
# - The word counting must be case-insensitive (e.g., "Apple" and "apple" should be treated as the same word).
#
# - The following punctuation marks should be ignored: `,`, `.`, `:`, `;`, `(`, `)`
#
# - The function should return a list of `(word, count)` tuples, sorted by the count in descending order.
#
# **Example:**
#
# - Input: `"./data/hello.txt"`
#
# - Output: `[('hello', 2), ('world', 1)]`

# %%
def word_count(filename):
    """Counts the occurrences of each word in a text file."""
    # ...

# %%
word_count("./data/hello.txt")

# %%
word_count("./data/golden.txt")

# %%
word_count("./data/en_emile.txt")

# %%
word_count("./data/ko_if_i_were_a_colleage_stsudent_again.txt")
