# %% [markdown]
# ## Employee Data Parser
#
# You are given a list of dictionaries, where each dictionary represents an employee and contains their name, department, and salary. Write a program that iterates through the list and calculates the total salary for a specific department. The program should ask the user to input the department name.
#
# **Example Data:**
# ```python
# employees = [
#     {"name": "Alice", "department": "Sales", "salary": 50000},
#     {"name": "Bob", "department": "Marketing", "salary": 60000},
#     {"name": "Charlie", "department": "Sales", "salary": 55000},
#     {"name": "David", "department": "Marketing", "salary": 62000}
# ]
# ```
#
# Example:
#
# Input: `Sales`
#
# Output: `Total salary for the Sales department: $105000`

# %%
employees = [
    {"name": "Alice", "department": "Sales", "salary": 50000},
    {"name": "Bob", "department": "Marketing", "salary": 60000},
    {"name": "Charlie", "department": "Sales", "salary": 55000},
    {"name": "David", "department": "Marketing", "salary": 62000}
]

def get_total_salary_for_department(dept):
    # your code here
    # ...

# %%
get_total_salary_for_department("Sales")
# Out:
# Total salary for the Sales department: $105000

# %%
get_total_salary_for_department("Marketing")
# Out:
# Total salary for the Marketing department: $122000
