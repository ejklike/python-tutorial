# %% [markdown]
# # Save Product Inventory to a CSV File
#
# Your goal is to write a Python function that takes a list of product dictionaries and saves them to a CSV file. This is a common task in data processing and reporting.
#
# > CSV is an abbreviation for comma separated values.
#
# **Requirements**
# 1. Function Definition:
#
# - Create a function named save_inventory.
#
# - It should accept two arguments: `inventory_data` (a list of dictionaries) and a `filename` string.
#
# 2. CSV File Format:
#
# - The first row of the CSV file must be the header row. The headers should be the keys from the dictionaries (`product_id`, `product_name`, `price`, `in_stock`).
#
# - Each subsequent row in the CSV file should correspond to a dictionary in the inventory_data list.

# %% [markdown]
# **Expected Output File (`inventory.csv`):**
#
# After running your script, a file named `inventory.csv` should be created. When you open it (with a text editor or a spreadsheet program), its content should look exactly like this:
#
# ```
# product_id,product_name,price,in_stock
# 101,Laptop,1200,15
# 102,Mouse,25,250
# 103,Keyboard,75,120
# 104,Monitor,300,45
# ```

# %%
# A list of products, where each product is a dictionary
products = [
    {'product_id': 'A101', 'product_name': 'Laptop', 'price': 1200, 'in_stock': 15},
    {'product_id': 'A102', 'product_name': 'Mouse', 'price': 25, 'in_stock': 250},
    {'product_id': 'A103', 'product_name': 'Keyboard', 'price': 75, 'in_stock': 120},
    {'product_id': 'A104', 'product_name': 'Monitor', 'price': 300, 'in_stock': 45}
]

# %%
def save_inventory(products, filename='inventory.csv'):
    # code here 
    # ...
