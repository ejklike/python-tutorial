# %% [markdown]
# # Restaurant Orders
#
# You are managing a restaurant's orders for a night. Each order is represented as a list, and all orders are stored in a main list.
#
# **Orders List:** `[['Pizza', 2], ['Salad', 1], ['Pizza', 1], ['Soup', 3], ['Salad', 1]]`
#
# **Problem:** Calculate the total quantity for each unique menu item and display the results. You should store the final totals in a dictionary.
#
# **Expected Output:**
# ```python
# {'Pizza': 3, 'Salad': 2, 'Soup': 3}
# ```
